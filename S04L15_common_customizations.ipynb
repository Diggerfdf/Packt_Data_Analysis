# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # 4 Common customization: colors, labels, ticks, tickmarks, limits and annotations

# %% [markdown]
# Now we are going to see how to change some of the elements of a plot. Matplotlib allows the user to customize almost every element of a plot.
# However there are some elements that we change more often, those are the ones that we review here.

# %%
# Generating data
x = np.linspace(-np.pi, np.pi, 200)
sine, cosine = np.sin(x), np.cos(x)

# %% [markdown]
# In this section we will go from this simple plot:

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, x, cosine);

# %% [markdown]
# to this plot:

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='red', label='Sine')
ax.plot(x, cosine, color='#165181', label='Cosine')

ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-1.2, 1.2)

ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_yticks([-1, 0, 1])

ax.set_xticklabels([r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'], size=17)
ax.set_yticklabels(['-1', '0', '+1'], size=17)

ax.legend(loc='upper left')

ax.text(-0.25, 0, '(0,0)') # x coord, y coord,
ax.text(np.pi-0.2, 0.05, r'$(\pi, 0)$', size=15)

ax.annotate('Origin', 
            xy = (0, 0), # where the arrow points to
            xytext = (1, -0.7), # location of the text
            arrowprops = dict(facecolor= 'blue'));

ax.axhline(0, color = 'black', alpha = 0.9) # horizontal line
ax.axvline(0, color = 'black', alpha = 0.9) # vertical
ax.grid();

# %% [markdown]
# ## 4.1 Colors

# %% [markdown]
# In the previous parts, you learned how matplotlib organizes plot-making by figures and axes. We broke down the components of a basic figure and learned how to create them. This section will go over some of the properties that are used throughout the library, especially those that tend to be used more often.
#
# Given that matplotlib is a plotting library, colors are associated with everything that is plotted in your figures. Matplotlib supports a very robust language for specifying colors that should be familiar to a wide variety of users.

# %% [markdown]
# ### 4.1.1 Colornames

# %% [markdown]
# First, colors can be given as strings. For very basic colors, you can even get away with just a single letter:

# %% [markdown]
# - b: blue
# - g: green
# - r: red
# - c: cyan
# - m: magenta
# - y: yellow
# - k: black
# - w: white

# %% [markdown]
# Other colornames that are allowed are the HTML/CSS colornames such as "burlywood" and "chartreuse" are valid. There are [147](https://www.w3schools.com/colors/colors_names.asp) color names.

# %% [markdown]
# ### 4.1.2 Hex values
#
# Colors can also be specified by supplying an HTML/CSS, such as '#0000FF' for blue

# %% [markdown]
# ### 4.1.3 256 Shades of Gray
#
# A gray level can be given instead of a color by passing a string representation of a number between 0 and 1, inclusive '0.0' is black, while '1.0' is white. '0.75' would be a lighter shade of gray.

# %% [markdown]
# ### 4.1.4 RGB[A] tuples

# %% [markdown]
# You may come upon instances where the previous ways of specifying colors do not work. This can sometimes happen in some of the deeper, stranger levels of the code. when all else fails, the universal language of colors for matplotlib is the RGB[A] tuple. This is the "Red", "Green", "Blue", and sometimes, "Alpha" tuple of floats in range of [0, 1]. One means full saturation of that channel, so a red RGBA tuple would be (1.0, 0.0, 0.0, 1.0), whereas partly transparent green RGBA tuple would be (0.0, 1.0, 0.0, 0.75). The documentation will usually specify whether it accepts RGB or RGBA tuples. Sometimes, a list of tuples would be required for multiple colors, and you can even supply a Nx3 or Nx4 array in such cases.
#
# In functions such as plot() and scatter(), while it may appear that they can take a color specification, what they really need is a "format specification", which includes color as part of the format. Unfortunately, such specifactions are string only and so RGB[A] tuples are not supported for such arguments(but you can still pass an RGB[A] tuple for a "color"argument).
#
# Note, oftentimes there is a separate argument for "alpha" whereever you can specify a color. The value for "alpha" will usualy take precedence over the alpha value in the RGBA tuple. There is no easy way around this problem.

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='burlywood')
ax.plot(x, cosine, color='#165181');

# %% [markdown]
# ## 4.2 Setting axis limits

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='red', label='Sine')
ax.plot(x, cosine, color='#165181', label='Cosine')

ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-1.2, 1.2);

# %% [markdown]
# ## 4.3 Setting ticks and tick labels

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='red', label='Sine')
ax.plot(x, cosine, color='#165181', label='Cosine')

ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-1.2, 1.2)

ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_yticks(np.arange(-1, 1.1, 0.5));

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='red', label='Sine')
ax.plot(x, cosine, color='#165181', label='Cosine')

ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-1.2, 1.2)

ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_yticks([-1, 0, 1])

ax.set_xticklabels([r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'], size=17)
ax.set_yticklabels(['-1', '0', '+1'], size=17)
# Out:
# [Text(0,0,'-1'), Text(0,0,'0'), Text(0,0,'+1')]

# %% [markdown]
# ## 4.4 Legend

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='red', label='Sine')
ax.plot(x, cosine, color='#165181', label='Cosine')

ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-1.2, 1.2)

ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_yticks([-1, 0, 1])

ax.set_xticklabels([r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'], size=17)
ax.set_yticklabels(['-1', '0', '+1'], size=17)

ax.legend(loc='upper left')

# %% [markdown]
# ## 4.5 Anotations

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='red', label='Sine')
ax.plot(x, cosine, color='#165181', label='Cosine')

ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-1.2, 1.2)

ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_yticks([-1, 0, 1])

ax.set_xticklabels([r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'], size=17)
ax.set_yticklabels(['-1', '0', '+1'], size=17)

ax.legend(loc='upper left')

ax.text(-0.25, 0, '(0,0)') # x coord, y coord,
ax.text(np.pi-0.2, 0.05, r'$(\pi, 0)$', size=15)

ax.annotate('Origin', 
            xy = (0, 0), # where the arrow points to
            xytext = (1, -0.7), # location of the text
            arrowprops = dict(facecolor= 'beige'));

# %% [markdown]
# ## 4.6 Grids, horizontal and vertical lines

# %%
fig, ax = plt.subplots()
ax.plot(x, sine, color='red', label='Sine')
ax.plot(x, cosine, color='#165181', label='Cosine')

ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-1.2, 1.2)

ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_yticks([-1, 0, 1])

ax.set_xticklabels([r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'], size=17)
ax.set_yticklabels(['-1', '0', '+1'], size=17)

ax.legend(loc='upper left')

ax.text(-0.25, 0, '(0,0)') # x coord, y coord,
ax.text(np.pi-0.2, 0.05, r'$(\pi, 0)$', size=15)

ax.annotate('Origin', 
            xy = (0, 0), # where the arrow points to
            xytext = (1, -0.7), # location of the text
            arrowprops = dict(facecolor= 'aquamarine'));

ax.axhline(0, color = 'black', alpha = 0.9) # horizontal line
ax.axvline(0, color = 'black', alpha = 0.9) # vertical
ax.grid();
